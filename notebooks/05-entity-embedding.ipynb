# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
EMBED_DIM = 13

# %%
df = pd.read_csv("../input/train.csv")
df.head()
# Out:
#    id  digit letter  0  1  2  3  4  5  6  ...  774  775  776  777  778  779  \
# 0   1      5      L  1  1  1  4  3  0  0  ...    2    1    0    1    2    4
# 1   2      0      B  0  4  0  0  4  1  1  ...    0    3    0    1    4    1
# 2   3      4      L  1  1  2  2  1  1  1  ...    3    3    3    0    2    0
# 3   4      9      D  1  2  0  2  0  4  0  ...    3    3    2    0    1    4
# 4   5      6      A  3  0  2  4  0  3  0  ...    4    4    3    2    1    3
#
#    780  781  782  783
# 0    4    4    3    4
# 1    4    2    1    2
# 2    3    0    2    2
# 3    0    0    1    1
# 4    4    3    1    2
#
# [5 rows x 787 columns]

# %%
class LetterEmbedding(nn.Module):
    def __init__(self):
        super(LetterEmbedding, self).__init__()
        self.embed = nn.Embedding(27, EMBED_DIM)
        
    def forward(self, x):
        pass

# %%
embed = nn.Embedding(27, EMBED_DIM)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ae5ddc38ec03> in <module>
# ----> 1 embed = nn.Embedding(27, embed_dim)
#
# NameError: name 'embed_dim' is not defined
